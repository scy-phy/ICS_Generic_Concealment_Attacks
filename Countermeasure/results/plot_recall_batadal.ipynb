# %%
import pandas as pd
import matplotlib.pyplot as plt
from cycler import cycler
import numpy as np
original = 1#0.610264
results_attack=pd.read_csv('./ensemble_normalized_acsac_performance_BATADAL.csv')


results_attack = results_attack.drop(['43'], axis =1)
results_attack
# Out:
#   Unnamed: 0         2         3         4         5         6         7  \
# 0        LTI  3.236313  2.821326  2.824207  2.723345  4.299715  4.262249
# 1    Sliding  0.274124  0.268640  0.268640  0.028508  0.028508  0.028508
# 2   Ensemble  1.040800  0.877602  0.877602  0.790174  1.245630  1.234805
#
#           8         9        10        15        20        25        30  \
# 0  3.838618  3.429399  3.985594  4.979832  5.501443  5.469746  5.469746
# 1  0.028508  0.112938  0.112938  0.273025  0.273025  0.273025  0.274124
# 2  1.112407  0.995004  1.154871  1.440467  1.589509  1.580350  1.580350
#
#          35        40
# 0  5.469746  5.469746
# 1  0.274124  0.033991
# 2  1.580350  1.580350

# %%
results_attack = results_attack.set_index('Unnamed: 0').transpose()
results_attack.index = results_attack.index.astype(int)

# %%
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
print(colors)
fig, ax = plt.subplots(figsize=(9,3))
ax.set_prop_cycle(cycler(color=[colors[2]]+[colors[0]]+[colors[1]]) + cycler(linestyle=['-','-','--'])+ cycler(marker=['s','o','^']))
#ax.hlines(y=round(original,2),xmin=0, xmax=3, color='r', linestyles='--',)
#fig, ax = plt.subplots()
for col in results_attack.columns:
    results_attack[col].plot(ax=ax)
ax.hlines(y=round(original,2),xmin=0, xmax=43, color='r', linestyles='--',)
plt.legend(np.append(results_attack.columns.values, 'Original = '+str(round(original,2))),bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',ncol=4, mode="expand", borderaxespad=0.)
plt.xticks(np.arange(0,43,5))
#ax.set_xlim(0.8,20.2)
#plt.ylim(-0.1,1.7)
plt.xlabel('# Controlled sensors k')
plt.ylabel('Normlaized Recall')
plt.savefig('plot_recall_constrained_acsac_batadal.pdf', bbox_inches = "tight")
plt.show()
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
results_attack
# Out:
# Unnamed: 0     Stale    Replay  Gaussian
# 2           0.440041  0.436484  0.527947
# 3           0.365346  0.359248  0.529472
# 4           0.013720  0.013720  0.472561
# 5           0.013720  0.013720  0.462907
# 6           0.013720  0.014736  0.457825
# 7           0.014228  0.015244  0.472561
# 8           0.013720  0.014736  0.455793
# 9           0.009146  0.012195  0.567581
# 10          0.008638  0.024898  0.585874
# 15          0.005081  0.013211  0.557419
# 20          0.014736  0.032520  0.676829
